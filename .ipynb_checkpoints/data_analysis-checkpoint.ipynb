# %%
import csv
import numpy as np
import sys
import os
from matplotlib import pyplot as plt
from skimage import io

# %% [markdown]
# # Parsing labels

# %%
def load_label(fname):
    label = []
    with open(fname) as f:
        reader = csv.reader(f)
        next(reader)
        for row in reader:
            label.append(row)
    return label

# %%
label = load_label("./data/train.csv")
import pandas as pd
label = pd.DataFrame(label)
num_classes = len(set(label[1]))
label

# %% [markdown]
# # Label's frequency :
#
# It is obvious that the classes aren't balanced.

# %%
label1 = pd.read_csv("./data/train.csv")
table1 = pd.crosstab(index = label1["label"], columns = "count")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'label'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-35405fad1879> in <module>
#       2 table = pd.crosstab(index = label[1], columns = "count")
#       3
# ----> 4 table1 = pd.crosstab(index = label1["label"], columns = "count")
#       5 label1
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'label'

# %% [markdown]
# # Sampling image

# %%
def sample_img():
    index = np.random.choice(range(len(label)))
    img = io.imread("./data/train/{}".format(label[0][index]))
    io.imshow(img)
    print("Class : {}".format(label[1][index]))
    print(img.shape)

# %%
sample_img()
# Out:
# Class : 73
# (181, 181, 3)

# %%
less_than_3 = table["count"] < 3
print(table.columns)
np.asarray((table[less_than_3].index)).astype(int)
# Out:
# Index(['count'], dtype='object', name='col_0')
# array([  0, 109,  11, 111, 114, 116, 117,  12, 120,  13, 130, 134, 137,
#        139,  14, 140, 142, 143, 145, 152, 165,  17, 170, 171, 177,  18,
#        181, 183, 190, 193, 198, 200, 203, 205, 206, 213, 214, 215,  22,
#        224, 228,  23, 230, 239, 240, 246, 249,  25, 252, 270, 271, 277,
#        284,  29, 295,   3,  30, 303, 308, 309,  31, 312, 313, 317, 318,
#        325, 329,  33, 330, 336, 337, 339, 340, 344, 348, 350, 351, 355,
#         36, 362, 367,  37, 370, 371,  38,  39, 395, 397,  40, 403, 407,
#         41, 410, 413, 415, 417, 421, 422, 427, 429,  43, 432, 441, 442,
#        447, 450, 452, 455, 458, 461, 462, 467, 470, 477, 478, 479, 486,
#        488,  49, 499,  50,  51, 520, 521, 524, 527,  53, 535, 537, 543,
#        544, 546, 550, 551, 556, 559, 560, 568, 569, 577, 579, 580, 591,
#        598, 599, 601, 603, 605, 613, 616,  62, 624, 633, 634, 635,  64,
#        640, 644,  65, 653, 655, 658, 660, 663,  67, 676, 677, 678, 679,
#         68, 680,  69,   7, 700, 704, 710, 712, 713,  72, 732, 737, 745,
#         75, 750, 752, 754, 769, 770, 776, 785, 786, 787, 791, 794, 798,
#        800, 804, 805, 808, 809,  81, 814, 817, 818, 825, 833, 836,  84,
#        842, 857, 858, 859, 860, 864,  88, 890,   9, 900, 903, 905,  91,
#        911, 912, 913, 915,  92, 922, 924, 927,  93, 931, 933, 936, 937,
#        939, 944, 947, 949, 962,  97, 973, 974,  98, 980, 982, 989, 990,
#        997, 999])

# %% [markdown]
# # Dimension

# %%
import os
from skimage import io

height = []
weight = []

files = os.listdir("./data/train")
path_root = "./data/train/"
for file in files:
    path = path_root + file
    img = io.imread(path)
    height.append( img.shape[1])
    weight.append(img.shape[0])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-3fa52c2ba565> in <module>
#       9 for file in files:
#      10     path = path_root + file
# ---> 11     img = io.imread(path)
#      12     height.append( img.shape[1])
#      13     weight.append(img.shape[0])
#
# /usr/local/lib/python3.6/dist-packages/skimage/io/_io.py in imread(fname, as_gray, plugin, flatten, **plugin_args)
#      60
#      61     with file_or_url_context(fname) as fname:
# ---> 62         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      63
#      64     if not hasattr(img, 'ndim'):
#
# /usr/local/lib/python3.6/dist-packages/skimage/io/manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     212                                (plugin, kind))
#     213
# --> 214     return func(*args, **kwargs)
#     215
#     216
#
# /usr/local/lib/python3.6/dist-packages/skimage/io/_plugins/pil_plugin.py in imread(fname, dtype, img_num, **kwargs)
#      34     if isinstance(fname, string_types):
#      35         with open(fname, 'rb') as f:
# ---> 36             im = Image.open(f)
#      37             return pil_to_ndarray(im, dtype=dtype, img_num=img_num)
#      38     else:
#
# /usr/lib/python3/dist-packages/PIL/Image.py in open(fp, mode)
#    2555         exclusive_fp = True
#    2556
# -> 2557     prefix = fp.read(16)
#    2558
#    2559     preinit()
#
# KeyboardInterrupt:

# %%
plt.hist(height)

# %%
plt.hist(weight)

# %%
table
# Out:
# col_0  count
# 1
# 0          2
# 1          3
# 10         4
# 100        4
# 101        9
# 102        5
# 103       10
# 104        8
# 105        6
# 106        3
# 107        3
# 108        6
# 109        1
# 11         2
# 110        4
# 111        2
# 112        6
# 113        4
# 114        2
# 115        4
# 116        2
# 117        1
# 118        4
# 119        5
# 12         2
# 120        1
# 121        3
# 122        4
# 123        3
# 124        4
# ..       ...
# 972        3
# 973        2
# 974        2
# 975        3
# 976        5
# 977        3
# 978        6
# 979        3
# 98         2
# 980        1
# 981        7
# 982        2
# 983        7
# 984        7
# 985        7
# 986        4
# 987        6
# 988        7
# 989        1
# 99         5
# 990        2
# 991        4
# 992        5
# 993        5
# 994        3
# 995        7
# 996        7
# 997        2
# 998        3
# 999        2
#
# [1000 rows x 1 columns]
